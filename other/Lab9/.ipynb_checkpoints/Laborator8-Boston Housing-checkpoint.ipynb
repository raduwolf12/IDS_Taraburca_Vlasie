# %% [markdown]
# # Laborator 8

# %% [markdown]
# ## Modele de regresie
#
# Folositi urmatoarele seturi de date:
# 1. [CPU Computer Hardware](https://archive.ics.uci.edu/ml/datasets/Computer+Hardware); excludeti din dataset coloanele: vendor name, model name, estimated relative performance; se va estima coloana "published relative performance".
# 1. [Boston Housing](http://archive.ics.uci.edu/ml/machine-learning-databases/housing/)
# 1. [Wisconsin Breast Cancer](http://www.dcc.fc.up.pt/~ltorgo/Regression/DataSets.html); cautati in panelul din stanga Wisconsin Breast Cancer si urmati pasii din "My personal Notes"
# 1. [Communities and Crime](http://archive.ics.uci.edu/ml/datasets/communities+and+crime); stergeti primele 5 dimensiuni si trasaturile cu missing values.
#
# Pentru fiecare set de date aplicati minim 5 modele de regresie din scikit learn. Pentru fiecare raportati: mean absolute error, mean squared error, median absolute error - a se vedea [sklearn.metrics](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) - folosind 5 fold cross validation. Valorile hiperparametrilor trebuie cautate cu grid search (cv=3)  si random search (n_iter dat de voi). Metrica folosita pentru cautarea hiperparametrilor va fi mean squared error. Raportati mediile rezultatelor atat pentru fold-urile de antrenare, cat si pentru cele de testare; indicatie: puteti folosi metoda `cross_validate` cu parametrul `return_train_score=True`, iar ca model un obiect de tip `GridSearchCV` sau `RandomizedSearchCV`.
#
# Rezultatele vor fi trecute intr-un dataframe. Intr-o stare intermediara, valorile vor fi calculate cu semnul minus: din motive de implementare, biblioteca sklearn transforma scorurile in numere negative; a se vedea imaginea de mai jos:
#
# ![intermediate report](./images/cpu_intermediate_blurred.png)
#
#
# Valorile vor fi aduse la interval pozitiv, apoi vor fi marcate cele maxime si minime; orientativ, se poate folosi imaginea de mai jos, reprezentand dataframe afisat in notebook; puteti folosi alte variante de styling pe dataframe precum la https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#.
#
# Se va crea un raport final in format HTML sau PDF - fisier(e) separat(e). Raportul trebuie sa contina minimal: numele setului de date si obiectul dataframe; preferabil sa se pastreze marcajul de culori realizat in notebook.
#
# ![report](./images/cpu_results_blurred.png)
#
# Notare:
# 1. Se acorda 20 de puncte din oficiu.
# 1. Optimizare si cuantificare de performanta a modelelor: 3 puncte pentru fiecare combinatie set de date + model = 60 de puncte
# 1. Documentare modele: numar modele * 2 puncte = 10 puncte. Documentati in jupyter notebook fiecare din modelele folosite, in limba romana. Puteti face o sectiune separata cu documentarea algoritmilor. Fiecare model trebuie sa aiba o descriere de minim 20 de randuri, minim o imagine asociata si minim 2 referinte bibliografice.
# 1. 10 puncte: export in format HTML sau PDF.

# %% [markdown]
# *Notare:* laboratorul va fi salvat in repository-ul de github si prezentat in saptamana 6-10 mai.

# %% [markdown]
# https://scikit-learn.org/stable/supervised_learning.html#supervised-learning

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_validate
import sklearn

# %%
ad1="http://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
names=['CRIM', ' ZN', ' INDUS','CHAS', 'NOX','RM','AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df2=pd.read_csv(ad1, names=names, sep="\s+")
df2[:5]
# Out:
#       CRIM    ZN   INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0    2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0    7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0    7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0    2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0    2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
#  ZN        506 non-null float64
#  INDUS     506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
mat=df2.values
X=mat[:, 0:-1]
y=mat[:, -1]
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# # LinearRegression

# %%
parameter_grid = {'fit_intercept': [True, False], 'normalize': [True, False], 'copy_X': [True, False]}
grid_search = GridSearchCV(estimator = LinearRegression(), param_grid=parameter_grid, cv=3, iid=False)

# %%
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()

# %%
df=pd.DataFrame()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'LinearRegression()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                 Model Type_of_Search  fit_time  test_neg_mean_absolute_error  \
# 0  LinearRegression()   GridSearchCv  0.045962                     -4.249969
#
#    test_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                   -37.131807                       -3.338714
#
#    train_neg_mean_absolute_error  train_neg_mean_squared_error  \
# 0                      -3.221565                    -20.735085
#
#    train_neg_median_absolute_error
# 0                        -2.393984

# %%
gs_random = RandomizedSearchCV(estimator=LinearRegression(), param_distributions=parameter_grid, cv= 3,n_iter=5, iid=False)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'LinearRegression()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                 Model      Type_of_Search  fit_time  \
# 0  LinearRegression()        GridSearchCv  0.045962
# 1  LinearRegression()  RandomizedSearchCV  0.024766
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615

# %% [markdown]
# # Ridge

# %%
param = {'alpha':[0.1,0.01, 0.001], 
         'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
grid_search = GridSearchCV(estimator = linear_model.Ridge(), param_grid=param, cv=3, iid=False, )
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),cv=5, return_train_score=True)

# %%
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'Ridge()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                 Model      Type_of_Search  fit_time  \
# 0  LinearRegression()        GridSearchCv  0.045962
# 1  LinearRegression()  RandomizedSearchCV  0.024766
# 2             Ridge()        GridSearchCv  0.329190
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880

# %%
gs_random = RandomizedSearchCV(estimator=linear_model.Ridge(), param_distributions=param, cv= 3,n_iter=15, iid=False)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'Ridge()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                 Model      Type_of_Search  fit_time  \
# 0  LinearRegression()        GridSearchCv  0.045962
# 1  LinearRegression()  RandomizedSearchCV  0.024766
# 2             Ridge()        GridSearchCv  0.329190
# 3             Ridge()  RandomizedSearchCV  0.221492
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798

# %% [markdown]
# # KNeighborsRegressor

# %%
parameter_grid = {'n_neighbors': list(range(1,10)), 'p': [1, 2, 3, 4.7]}
grid_search = GridSearchCV(estimator =KNeighborsRegressor(), param_grid=parameter_grid, cv=3, iid=False)
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),cv=5, return_train_score=True)

# %%
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'KNeighborsRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                    Model      Type_of_Search  fit_time  \
# 0     LinearRegression()        GridSearchCv  0.045962
# 1     LinearRegression()  RandomizedSearchCV  0.024766
# 2                Ridge()        GridSearchCv  0.329190
# 3                Ridge()  RandomizedSearchCV  0.221492
# 4  KNeighborsRegressor()        GridSearchCv  1.463316
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333

# %%
gs_random = RandomizedSearchCV(estimator=KNeighborsRegressor(), param_distributions=parameter_grid, cv= 3,n_iter=15, iid=False)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'KNeighborsRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                    Model      Type_of_Search  fit_time  \
# 0     LinearRegression()        GridSearchCv  0.045962
# 1     LinearRegression()  RandomizedSearchCV  0.024766
# 2                Ridge()        GridSearchCv  0.329190
# 3                Ridge()  RandomizedSearchCV  0.221492
# 4  KNeighborsRegressor()        GridSearchCv  1.463316
# 5  KNeighborsRegressor()  RandomizedSearchCV  0.664099
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
# 5                     -4.695868                   -50.637290
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
# 5                       -3.231667                      -1.992877
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333
# 5                     -9.364885                        -1.320000

# %% [markdown]
# # MLPRegressor

# %%
paramsM = {'activation' : ['identity', 'logistic', 'tanh', 'relu'], 
          'solver' : ['lbfgs', 'sgd', 'adam'],
          'alpha':[0.1, 0.001, 0.0001]}
grid_search = GridSearchCV(estimator =MLPRegressor(max_iter=10000), param_grid=paramsM, cv=3, iid=False, verbose=10, n_jobs=-1)
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),cv=5, return_train_score=True)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  2.4min finished
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1792s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.5922s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  2.1min finished
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1968s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.3944s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  2.1min finished
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1562s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.6320s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  2.2min finished
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  2.2min finished

# %%
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'MLPRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                    Model      Type_of_Search    fit_time  \
# 0     LinearRegression()        GridSearchCv    0.045962
# 1     LinearRegression()  RandomizedSearchCV    0.024766
# 2                Ridge()        GridSearchCv    0.329190
# 3                Ridge()  RandomizedSearchCV    0.221492
# 4  KNeighborsRegressor()        GridSearchCv    1.463316
# 5  KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6         MLPRegressor()        GridSearchCv  132.075395
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
# 5                     -4.695868                   -50.637290
# 6                     -3.628380                   -29.089531
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
# 5                       -3.231667                      -1.992877
# 6                       -2.624865                      -2.979582
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333
# 5                     -9.364885                        -1.320000
# 6                    -19.381624                        -2.131734

# %%
gs_random = RandomizedSearchCV(estimator=MLPRegressor(max_iter=10000), param_distributions=paramsM, cv= 3,n_iter=20, iid=False, verbose=10, n_jobs=-1)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'MLPRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.4min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   37.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   37.3s finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min finished
#                    Model      Type_of_Search    fit_time  \
# 0     LinearRegression()        GridSearchCv    0.045962
# 1     LinearRegression()  RandomizedSearchCV    0.024766
# 2                Ridge()        GridSearchCv    0.329190
# 3                Ridge()  RandomizedSearchCV    0.221492
# 4  KNeighborsRegressor()        GridSearchCv    1.463316
# 5  KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6         MLPRegressor()        GridSearchCv  132.075395
# 7         MLPRegressor()  RandomizedSearchCV   70.568015
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
# 5                     -4.695868                   -50.637290
# 6                     -3.628380                   -29.089531
# 7                     -3.719170                   -29.576950
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
# 5                       -3.231667                      -1.992877
# 6                       -2.624865                      -2.979582
# 7                       -2.827409                      -3.178800
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333
# 5                     -9.364885                        -1.320000
# 6                    -19.381624                        -2.131734
# 7                    -20.346960                        -2.439058

# %% [markdown]
# # SVR

# %%
param = {'C': [1.0, 0.5], 
          'kernel': ['linear','rbf', 'poly']}
grid_search = GridSearchCV(estimator = SVR(gamma='auto'), param_grid=param, cv=3, iid=False)
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),cv=5, return_train_score=True)

# %%
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'SVR()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                    Model      Type_of_Search    fit_time  \
# 0     LinearRegression()        GridSearchCv    0.045962
# 1     LinearRegression()  RandomizedSearchCV    0.024766
# 2                Ridge()        GridSearchCv    0.329190
# 3                Ridge()  RandomizedSearchCV    0.221492
# 4  KNeighborsRegressor()        GridSearchCv    1.463316
# 5  KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6         MLPRegressor()        GridSearchCv  132.075395
# 7         MLPRegressor()  RandomizedSearchCV   70.568015
# 8                  SVR()        GridSearchCv    0.096090
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
# 5                     -4.695868                   -50.637290
# 6                     -3.628380                   -29.089531
# 7                     -3.719170                   -29.576950
# 8                     -3.854555                   -36.298241
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
# 5                       -3.231667                      -1.992877
# 6                       -2.624865                      -2.979582
# 7                       -2.827409                      -3.178800
# 8                       -2.456058                      -3.375643
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333
# 5                     -9.364885                        -1.320000
# 6                    -19.381624                        -2.131734
# 7                    -20.346960                        -2.439058
# 8                    -30.389299                        -1.969299

# %%
gs_random = RandomizedSearchCV(estimator= SVR(gamma='auto'), param_distributions=param, cv= 3,n_iter=5, iid=False)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'SVR()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                    Model      Type_of_Search    fit_time  \
# 0     LinearRegression()        GridSearchCv    0.045962
# 1     LinearRegression()  RandomizedSearchCV    0.024766
# 2                Ridge()        GridSearchCv    0.329190
# 3                Ridge()  RandomizedSearchCV    0.221492
# 4  KNeighborsRegressor()        GridSearchCv    1.463316
# 5  KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6         MLPRegressor()        GridSearchCv  132.075395
# 7         MLPRegressor()  RandomizedSearchCV   70.568015
# 8                  SVR()        GridSearchCv    0.096090
# 9                  SVR()  RandomizedSearchCV    0.073128
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -4.249969                   -37.131807
# 1                     -4.249969                   -37.131807
# 2                     -4.189052                   -36.230223
# 3                     -4.190142                   -36.252900
# 4                     -4.727312                   -50.711309
# 5                     -4.695868                   -50.637290
# 6                     -3.628380                   -29.089531
# 7                     -3.719170                   -29.576950
# 8                     -3.854555                   -36.298241
# 9                     -3.940338                   -38.191231
#
#    test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                       -3.338714                      -3.221565
# 1                       -3.338714                      -7.612202
# 2                       -3.234592                      -3.212404
# 3                       -3.232664                      -3.212276
# 4                       -3.276000                      -2.000114
# 5                       -3.231667                      -1.992877
# 6                       -2.624865                      -2.979582
# 7                       -2.827409                      -3.178800
# 8                       -2.456058                      -3.375643
# 9                       -2.482266                      -3.424488
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                    -20.735085                        -2.393984
# 1                    -90.815276                        -6.979615
# 2                    -20.743625                        -2.374880
# 3                    -20.743154                        -2.377798
# 4                     -9.195001                        -1.345333
# 5                     -9.364885                        -1.320000
# 6                    -19.381624                        -2.131734
# 7                    -20.346960                        -2.439058
# 8                    -30.389299                        -1.969299
# 9                    -31.478762                        -1.989606

# %% [markdown]
# # DecisionTreeRegressor

# %%
params = {'max_features': ['auto', 'sqrt', 'log2'],
          'min_samples_split':list(range(2,15)), 
          'min_samples_leaf':list(range(2,11)),
         }
grid_search = GridSearchCV(estimator = DecisionTreeRegressor(), param_grid=params, cv=3, iid=False)
cv_results = cross_validate(grid_search, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),cv=5, return_train_score=True)

# %%
a=cv_results['train_neg_mean_squared_error'].mean()
b=cv_results['train_neg_mean_absolute_error'].mean()
c=cv_results['train_neg_median_absolute_error'].mean()
d=cv_results['test_neg_mean_squared_error'].mean()
e=cv_results['test_neg_mean_absolute_error'].mean()
f=cv_results['test_neg_median_absolute_error'].mean()
g=cv_results['fit_time'].mean()
df=df.append( {'Type_of_Search':'GridSearchCv','Model':'DecisionTreeRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                       Model      Type_of_Search    fit_time  \
# 0        LinearRegression()        GridSearchCv    0.045962
# 1        LinearRegression()  RandomizedSearchCV    0.024766
# 2                   Ridge()        GridSearchCv    0.329190
# 3                   Ridge()  RandomizedSearchCV    0.221492
# 4     KNeighborsRegressor()        GridSearchCv    1.463316
# 5     KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6            MLPRegressor()        GridSearchCv  132.075395
# 7            MLPRegressor()  RandomizedSearchCV   70.568015
# 8                     SVR()        GridSearchCv    0.096090
# 9                     SVR()  RandomizedSearchCV    0.073128
# 10  DecisionTreeRegressor()        GridSearchCv    1.343588
#
#     test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                      -4.249969                   -37.131807
# 1                      -4.249969                   -37.131807
# 2                      -4.189052                   -36.230223
# 3                      -4.190142                   -36.252900
# 4                      -4.727312                   -50.711309
# 5                      -4.695868                   -50.637290
# 6                      -3.628380                   -29.089531
# 7                      -3.719170                   -29.576950
# 8                      -3.854555                   -36.298241
# 9                      -3.940338                   -38.191231
# 10                     -4.153005                   -42.196748
#
#     test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                        -3.338714                      -3.221565
# 1                        -3.338714                      -7.612202
# 2                        -3.234592                      -3.212404
# 3                        -3.232664                      -3.212276
# 4                        -3.276000                      -2.000114
# 5                        -3.231667                      -1.992877
# 6                        -2.624865                      -2.979582
# 7                        -2.827409                      -3.178800
# 8                        -2.456058                      -3.375643
# 9                        -2.482266                      -3.424488
# 10                       -2.591710                      -2.390959
#
#     train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                     -20.735085                        -2.393984
# 1                     -90.815276                        -6.979615
# 2                     -20.743625                        -2.374880
# 3                     -20.743154                        -2.377798
# 4                      -9.195001                        -1.345333
# 5                      -9.364885                        -1.320000
# 6                     -19.381624                        -2.131734
# 7                     -20.346960                        -2.439058
# 8                     -30.389299                        -1.969299
# 9                     -31.478762                        -1.989606
# 10                    -15.235564                        -1.531290

# %%
gs_random = RandomizedSearchCV(estimator= DecisionTreeRegressor(), param_distributions=params, cv= 3,n_iter=50, iid=False)
cv_random = cross_validate(gs_random, X, y,
                            scoring=('neg_mean_squared_error', 'neg_mean_absolute_error','neg_median_absolute_error'),
                            cv=5, return_train_score=True)
a=cv_random['train_neg_mean_squared_error'].mean()
b=cv_random['train_neg_mean_absolute_error'].mean()
c=cv_random['train_neg_median_absolute_error'].mean()
d=cv_random['test_neg_mean_squared_error'].mean()
e=cv_random['test_neg_mean_absolute_error'].mean()
f=cv_random['test_neg_median_absolute_error'].mean()
g=cv_random['fit_time'].mean()
df=df.append( {'Type_of_Search':'RandomizedSearchCV','Model':'DecisionTreeRegressor()','train_neg_mean_squared_error':a,
               'train_neg_mean_absolute_error':b, 'train_neg_median_absolute_error':c,
               'test_neg_mean_squared_error':d,'test_neg_mean_absolute_error':e,
               'test_neg_median_absolute_error':f, 'fit_time':g}, ignore_index=True)
df
# Out:
#                       Model      Type_of_Search    fit_time  \
# 0        LinearRegression()        GridSearchCv    0.045962
# 1        LinearRegression()  RandomizedSearchCV    0.024766
# 2                   Ridge()        GridSearchCv    0.329190
# 3                   Ridge()  RandomizedSearchCV    0.221492
# 4     KNeighborsRegressor()        GridSearchCv    1.463316
# 5     KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6            MLPRegressor()        GridSearchCv  132.075395
# 7            MLPRegressor()  RandomizedSearchCV   70.568015
# 8                     SVR()        GridSearchCv    0.096090
# 9                     SVR()  RandomizedSearchCV    0.073128
# 10  DecisionTreeRegressor()        GridSearchCv    1.343588
# 11  DecisionTreeRegressor()  RandomizedSearchCV    0.189324
#
#     test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                      -4.249969                   -37.131807
# 1                      -4.249969                   -37.131807
# 2                      -4.189052                   -36.230223
# 3                      -4.190142                   -36.252900
# 4                      -4.727312                   -50.711309
# 5                      -4.695868                   -50.637290
# 6                      -3.628380                   -29.089531
# 7                      -3.719170                   -29.576950
# 8                      -3.854555                   -36.298241
# 9                      -3.940338                   -38.191231
# 10                     -4.153005                   -42.196748
# 11                     -3.964608                   -35.790596
#
#     test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                        -3.338714                      -3.221565
# 1                        -3.338714                      -7.612202
# 2                        -3.234592                      -3.212404
# 3                        -3.232664                      -3.212276
# 4                        -3.276000                      -2.000114
# 5                        -3.231667                      -1.992877
# 6                        -2.624865                      -2.979582
# 7                        -2.827409                      -3.178800
# 8                        -2.456058                      -3.375643
# 9                        -2.482266                      -3.424488
# 10                       -2.591710                      -2.390959
# 11                       -2.536604                      -1.958577
#
#     train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                     -20.735085                        -2.393984
# 1                     -90.815276                        -6.979615
# 2                     -20.743625                        -2.374880
# 3                     -20.743154                        -2.377798
# 4                      -9.195001                        -1.345333
# 5                      -9.364885                        -1.320000
# 6                     -19.381624                        -2.131734
# 7                     -20.346960                        -2.439058
# 8                     -30.389299                        -1.969299
# 9                     -31.478762                        -1.989606
# 10                    -15.235564                        -1.531290
# 11                     -9.282022                        -1.341752

# %%
df['train_neg_mean_squared_error']=df['train_neg_mean_squared_error'].abs()
df['train_neg_mean_absolute_error']=df['train_neg_mean_absolute_error'].abs()
df['train_neg_median_absolute_error']=df['train_neg_median_absolute_error'].abs()
df['test_neg_mean_squared_error']=df['test_neg_mean_squared_error'].abs()
df['test_neg_mean_absolute_error']=df['test_neg_mean_absolute_error'].abs()
df['test_neg_median_absolute_error' ]=df['test_neg_median_absolute_error'].abs()
df
# Out:
#                       Model      Type_of_Search    fit_time  \
# 0        LinearRegression()        GridSearchCv    0.045962
# 1        LinearRegression()  RandomizedSearchCV    0.024766
# 2                   Ridge()        GridSearchCv    0.329190
# 3                   Ridge()  RandomizedSearchCV    0.221492
# 4     KNeighborsRegressor()        GridSearchCv    1.463316
# 5     KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6            MLPRegressor()        GridSearchCv  132.075395
# 7            MLPRegressor()  RandomizedSearchCV   70.568015
# 8                     SVR()        GridSearchCv    0.096090
# 9                     SVR()  RandomizedSearchCV    0.073128
# 10  DecisionTreeRegressor()        GridSearchCv    1.343588
# 11  DecisionTreeRegressor()  RandomizedSearchCV    0.189324
#
#     test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                       4.249969                    37.131807
# 1                       4.249969                    37.131807
# 2                       4.189052                    36.230223
# 3                       4.190142                    36.252900
# 4                       4.727312                    50.711309
# 5                       4.695868                    50.637290
# 6                       3.628380                    29.089531
# 7                       3.719170                    29.576950
# 8                       3.854555                    36.298241
# 9                       3.940338                    38.191231
# 10                      4.153005                    42.196748
# 11                      3.964608                    35.790596
#
#     test_neg_median_absolute_error  train_neg_mean_absolute_error  \
# 0                         3.338714                       3.221565
# 1                         3.338714                       7.612202
# 2                         3.234592                       3.212404
# 3                         3.232664                       3.212276
# 4                         3.276000                       2.000114
# 5                         3.231667                       1.992877
# 6                         2.624865                       2.979582
# 7                         2.827409                       3.178800
# 8                         2.456058                       3.375643
# 9                         2.482266                       3.424488
# 10                        2.591710                       2.390959
# 11                        2.536604                       1.958577
#
#     train_neg_mean_squared_error  train_neg_median_absolute_error
# 0                      20.735085                         2.393984
# 1                      90.815276                         6.979615
# 2                      20.743625                         2.374880
# 3                      20.743154                         2.377798
# 4                       9.195001                         1.345333
# 5                       9.364885                         1.320000
# 6                      19.381624                         2.131734
# 7                      20.346960                         2.439058
# 8                      30.389299                         1.969299
# 9                      31.478762                         1.989606
# 10                     15.235564                         1.531290
# 11                      9.282022                         1.341752

# %%
df = df.rename(columns={'train_neg_mean_squared_error': 'train_mean_squared_error', 'train_neg_mean_absolute_error': 'train_mean_absolute_error', 
                       'train_neg_median_absolute_error':'train_median_absolute_error','test_neg_mean_squared_error':'test_mean_squared_error',
                       'test_neg_mean_absolute_error':'test_mean_absolute_error', 'test_neg_median_absolute_error':'test_median_absolute_error'})
df
# Out:
#                       Model      Type_of_Search    fit_time  \
# 0        LinearRegression()        GridSearchCv    0.045962
# 1        LinearRegression()  RandomizedSearchCV    0.024766
# 2                   Ridge()        GridSearchCv    0.329190
# 3                   Ridge()  RandomizedSearchCV    0.221492
# 4     KNeighborsRegressor()        GridSearchCv    1.463316
# 5     KNeighborsRegressor()  RandomizedSearchCV    0.664099
# 6            MLPRegressor()        GridSearchCv  132.075395
# 7            MLPRegressor()  RandomizedSearchCV   70.568015
# 8                     SVR()        GridSearchCv    0.096090
# 9                     SVR()  RandomizedSearchCV    0.073128
# 10  DecisionTreeRegressor()        GridSearchCv    1.343588
# 11  DecisionTreeRegressor()  RandomizedSearchCV    0.189324
#
#     test_mean_absolute_error  test_mean_squared_error  \
# 0                   4.249969                37.131807
# 1                   4.249969                37.131807
# 2                   4.189052                36.230223
# 3                   4.190142                36.252900
# 4                   4.727312                50.711309
# 5                   4.695868                50.637290
# 6                   3.628380                29.089531
# 7                   3.719170                29.576950
# 8                   3.854555                36.298241
# 9                   3.940338                38.191231
# 10                  4.153005                42.196748
# 11                  3.964608                35.790596
#
#     test_median_absolute_error  train_mean_absolute_error  \
# 0                     3.338714                   3.221565
# 1                     3.338714                   7.612202
# 2                     3.234592                   3.212404
# 3                     3.232664                   3.212276
# 4                     3.276000                   2.000114
# 5                     3.231667                   1.992877
# 6                     2.624865                   2.979582
# 7                     2.827409                   3.178800
# 8                     2.456058                   3.375643
# 9                     2.482266                   3.424488
# 10                    2.591710                   2.390959
# 11                    2.536604                   1.958577
#
#     train_mean_squared_error  train_median_absolute_error
# 0                  20.735085                     2.393984
# 1                  90.815276                     6.979615
# 2                  20.743625                     2.374880
# 3                  20.743154                     2.377798
# 4                   9.195001                     1.345333
# 5                   9.364885                     1.320000
# 6                  19.381624                     2.131734
# 7                  20.346960                     2.439058
# 8                  30.389299                     1.969299
# 9                  31.478762                     1.989606
# 10                 15.235564                     1.531290
# 11                  9.282022                     1.341752

# %%
def highlight_max(df):
    is_max = df == df.max()
    return ['background-color: red' if v else '' for v in is_max]

def highlight_min(df):
    is_min = df == df.min()
    return ['background-color: yellow ' if a else '' for a in is_min]


df.style.apply(highlight_max)\
.apply(highlight_min)
# Out:
# <style  type="text/css" >
#     #T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col5 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col2 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col5 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col6 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col7 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col8 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow3_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow4_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow4_col3 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow4_col4 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow4_col7 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow5_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow5_col8 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow6_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow6_col2 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow6_col3 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow6_col4 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow7_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow8_col0 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow8_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow8_col5 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow9_col0 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow9_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow10_col0 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow10_col1 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow11_col0 {
#             : ;
#             background-color:  yellow ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow11_col1 {
#             background-color:  red;
#             : ;
#         }    #T_91b29e48_6ccf_11e9_af11_f8281953888erow11_col6 {
#             : ;
#             background-color:  yellow ;
#         }</style><table id="T_91b29e48_6ccf_11e9_af11_f8281953888e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Type_of_Search</th>        <th class="col_heading level0 col2" >fit_time</th>        <th class="col_heading level0 col3" >test_mean_absolute_error</th>        <th class="col_heading level0 col4" >test_mean_squared_error</th>        <th class="col_heading level0 col5" >test_median_absolute_error</th>        <th class="col_heading level0 col6" >train_mean_absolute_error</th>        <th class="col_heading level0 col7" >train_mean_squared_error</th>        <th class="col_heading level0 col8" >train_median_absolute_error</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_91b29e48_6ccf_11e9_af11_f8281953888elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col0" class="data row0 col0" >LinearRegression()</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col1" class="data row0 col1" >GridSearchCv</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col2" class="data row0 col2" >0.0459619</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col3" class="data row0 col3" >4.24997</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col4" class="data row0 col4" >37.1318</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col5" class="data row0 col5" >3.33871</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col6" class="data row0 col6" >3.22156</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col7" class="data row0 col7" >20.7351</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow0_col8" class="data row0 col8" >2.39398</td>
#             </tr>
#             <tr>
#                         <th id="T_91b29e48_6ccf_11e9_af11_f8281953888elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col0" class="data row1 col0" >LinearRegression()</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col1" class="data row1 col1" >RandomizedSearchCV</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col2" class="data row1 col2" >0.0247657</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col3" class="data row1 col3" >4.24997</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col4" class="data row1 col4" >37.1318</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col5" class="data row1 col5" >3.33871</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col6" class="data row1 col6" >7.6122</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col7" class="data row1 col7" >90.8153</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow1_col8" class="data row1 col8" >6.97961</td>
#             </tr>
#             <tr>
#                         <th id="T_91b29e48_6ccf_11e9_af11_f8281953888elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col0" class="data row2 col0" >Ridge()</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col1" class="data row2 col1" >GridSearchCv</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col2" class="data row2 col2" >0.32919</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col3" class="data row2 col3" >4.18905</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col4" class="data row2 col4" >36.2302</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col5" class="data row2 col5" >3.23459</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col6" class="data row2 col6" >3.2124</td>
#                         <td id="T_91b29e48_6ccf_11e9_af11_f8281953888erow2_col7" class="data
